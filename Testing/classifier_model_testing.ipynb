# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
import os,sys
models_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'models'))
sys.path.append(models_path)
from domain_classifier import Classifier
from Data_processing.processing import fetchXJTUData,fetchTJUData,fetchMITData,fetchHUSTData
# Out:
#   Cell In[21], line 13
#     from Data processing.processing import fetchXJTUData,fetchTJUData,fetchMITData,fetchHUSTData
#               ^
# SyntaxError: invalid syntax

# %%
xjtu_da

# %%
data_1=[]
data_2=[]
data_3=[]
data_4=[]
for i in range(len(xjtu_data)):
  for j in range(len(xjtu_data[i])):
    df=xjtu_data[i][j]
    df=df.drop(columns=['SOH']) 
    df['battery']=0
    data_1.append(df)

for i in range(len(tju_data)):
  for j in range(len(tju_data[i])):
    df=tju_data[i][j]
    df=df.drop(columns=['SOH'])
    df['battery']=1
    data_2.append(df)

for i in range(len(mit_data)):
  df=mit_data[i]
  df=df.drop(columns=['SOH'])
  df['battery']=2
  data_3.append(df)

for i in range(len(hust_data)):
  df=hust_data[i]
  df=df.drop(columns='SOH')
  df['battery']=3
  data_4.append(df)
# Out:
# ['..\\Data\\classification_test_data\\CY45-05_1-#21.csv']

# %%
test_data[0]
# Out:
#      voltage mean  voltage std  voltage kurtosis  voltage skewness      CC Q  \
# 0        4.098911     0.062180         -1.307570          0.053435  0.629464
# 1        4.099183     0.060964         -1.302153          0.054210  0.614325
# 2        4.096970     0.060941         -1.297056          0.068005  0.615330
# 3        4.099074     0.061072         -1.301899          0.056075  0.616700
# 4        4.097818     0.060954         -1.298419          0.063213  0.616306
# ..            ...          ...               ...               ...       ...
# 604      4.096074     0.060459         -1.252201          0.100114  0.564952
# 605      4.096430     0.060542         -1.254755          0.096661  0.564575
# 606      4.095050     0.059157         -1.247173          0.105636  0.555528
# 607      4.094719     0.059020         -1.244973          0.104893  0.554217
# 608      4.097818     0.060578         -1.258845          0.092302  0.560861
#
# ...

# %%
classifier=Classifier()
classifier.testing(test_data)
# Out:
# Printing1....
# 1
# Printing2....
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step
# Test index -->  0
# Total sample:  589
# Correct prediction :  589
# Wrong prediction :  0
# accuracy :  1.0
