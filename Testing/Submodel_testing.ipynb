# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os,sys
models_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'models'))
sys.path.append(models_path)
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Bidirectional, Dropout, Dense, Input
from utils import dataCleaning
from utils import dataImputation
from tensorflow.keras.models import load_model
from fine_tuning import ModelFinetuning

# %%
# Testing
folder_path=os.path.join('..','Data','exclusive_test_data')
files=[os.path.join(folder_path,f) for f in os.listdir(folder_path)]
test_data=[pd.read_csv(f) for f in files]
epochs=50
timesteps=20
batch_size=32
training_data=dataImputation(test_data)
X,Y,scalling,Y_actual=dataCleaning(test_data)
feature_size=X.shape[2]
model=ModelFinetuning()
model_name='xjtu' # Can be changed based on choice of (xjtu,tju,hust,mit)
model.testing(test_data,timesteps,feature_size,model_name)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step
# Error:  0.03310777324115128
# RMSE: 0.04344104519021888

# %%
# Testing
folder_path=os.path.join('..','Data','exclusive_test_data')
files=[os.path.join(folder_path,f) for f in os.listdir(folder_path)]
test_data=[pd.read_csv(f) for f in files]
epochs=50
timesteps=20
batch_size=32
training_data=dataImputation(test_data)
X,Y,scalling,Y_actual=dataCleaning(test_data)
feature_size=X.shape[2]
model=ModelFinetuning()
model_name='tju' # Can be changed based on choice of (xjtu,tju,hust,mit)
model.testing(test_data,timesteps,feature_size,model_name)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step
# Error:  0.02721171189719566
# RMSE: 0.033994293646602766

# %%
# Testing
folder_path=os.path.join('..','Data','exclusive_test_data')
files=[os.path.join(folder_path,f) for f in os.listdir(folder_path)]
test_data=[pd.read_csv(f) for f in files]
epochs=50
timesteps=20
batch_size=32
training_data=dataImputation(test_data)
X,Y,scalling,Y_actual=dataCleaning(test_data)
feature_size=X.shape[2]
model=ModelFinetuning()
model_name='mit' # Can be changed based on choice of (xjtu,tju,hust,mit)
model.testing(test_data,timesteps,feature_size,model_name)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step
# Error:  0.03517067177797053
# RMSE: 0.049107620456003656

# %%
# Testing
folder_path=os.path.join('..','Data','exclusive_test_data')
files=[os.path.join(folder_path,f) for f in os.listdir(folder_path)]
test_data=[pd.read_csv(f) for f in files]
epochs=50
timesteps=20
batch_size=32
training_data=dataImputation(test_data)
X,Y,scalling,Y_actual=dataCleaning(test_data)
feature_size=X.shape[2]
model=ModelFinetuning()
model_name='hust' # Can be changed based on choice of (xjtu,tju,hust,mit)
model.testing(test_data,timesteps,feature_size,model_name)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step
# Error:  0.02409786132241929
# RMSE: 0.029666222648747322
