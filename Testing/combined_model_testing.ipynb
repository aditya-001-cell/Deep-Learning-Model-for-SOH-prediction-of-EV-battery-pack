# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import random
import os,sys
models_path = os.path.abspath(os.path.join(os.getcwd(), '..', 'models'))
sys.path.append(models_path)
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Bidirectional, Dropout, Dense, Input
from utils import dataCleaning
from utils import dataImputation
from tensorflow.keras.models import load_model
from fine_tuning import ModelFinetuning
from combined_model import CombinedModel

# %%
# Testing
folder_path=os.path.join('..','Data','exclusive_test_data')
files=[os.path.join(folder_path,f) for f in os.listdir(folder_path)]
test_data=[pd.read_csv(f) for f in files]
epochs=50
timesteps=20
batch_size=32
test_data=dataImputation(test_data)
feature_size=17
model=CombinedModel()
model.calculateSOH(test_data)
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
# MAE: 0.030087158816599208
# RMSE: 0.040086261276023966
